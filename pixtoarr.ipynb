# %%
from PIL import Image
import numpy as np
def isqrt(n):
    i = int(math.sqrt(n) + 0.5)
    if i**2 == n:
        return i

# %%
width, height = Image.open("lena_gray.bmp").size

# %%
width
# Out:
# 512

# %%
height
# Out:
# 512

# %%
im = Image.open("lena_gray.bmp")
pix_val = list(im.getdata())

# %%
pix_val
# Out:
# [160,
#  160,
#  160,
#  159,
#  161,
#  156,
#  161,
#  159,
#  162,
#  159,
#  160,
#  158,
#  154,
#  162,
#  158,
#  154,
#  156,
#  155,
#  160,
#  160,
#  153,
#  156,
#  154,
#  156,
#  154,
#  156,
#  154,
#  152,
#  155,
#  153,
#  153,
#  155,
#  153,
#  157,
#  155,
#  158,
#  157,
#  164,
#  160,
#  165,
#  166,
#  165,
#  165,
#  171,
#  170,
#  174,
#  172,
#  169,
#  171,
#  171,
#  166,
#  174,
#  168,
#  165,
#  162,
#  159,
#  149,
#  149,
#  153,
#  140,
#  130,
#  122,
#  119,
#  107,
#  101,
#  100,
#  96,
#  94,
#  92,
#  98,
#  103,
#  98,
#  104,
#  102,
#  105,
#  106,
#  107,
#  107,
#  106,
#  111,
#  112,
#  110,
#  109,
#  108,
#  107,
#  111,
#  110,
#  111,
#  110,
#  109,
#  109,
#  109,
#  112,
#  111,
#  109,
#  111,
#  110,
#  111,
#  111,
#  109,
#  107,
#  108,
#  109,
#  110,
#  110,
#  113,
#  118,
#  113,
#  116,
#  119,
#  123,
#  120,
#  115,
#  124,
#  122,
#  123,
#  126,
#  124,
#  122,
#  126,
#  126,
#  131,
#  131,
#  124,
#  125,
# ...

# %%
l=len(pix_val)
a=np.array(pix_val)
p=isqrt(l)
p
# Out:
# 512

# %%
B = a.reshape(p,p)

# %%
B
# Out:
# array([[160, 160, 160, ..., 169, 154, 129],
#        [161, 160, 159, ..., 168, 154, 129],
#        [160, 161, 160, ..., 168, 154, 129],
#        ...,
#        [ 50,  49,  55, ..., 106, 103, 104],
#        [ 49,  50,  58, ..., 107, 109, 111],
#        [ 50,  49,  59, ..., 107, 108, 112]])
